# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# np.random.random() -> [0, 1]の乱数を返す
print(np.random.random())

a = []
for i in range(1000):
    a.append(np.random.random())
a.sort()

plt.plot(a)
# Out:
# 0.9138867991092874

# %%
# np.random.randn() -> 標準正規分布に従った乱数を返す
print(np.random.randn())

b = []
for i in range(1000):
    b.append(np.random.randn())
b.sort()

plt.plot(b)
# Out:
# 1.2209936905576728

# %%
# 配列にしたい場合はnp.random.rand(rows, cols)
print(np.random.rand(2,4))

print(np.random.randn(2,4))
# Out:
# [[0.13049771 0.22972138 0.14184558 0.59717149]
#  [0.90376562 0.60374623 0.75750945 0.61177918]]
# [[-0.4578763  -0.06988679  2.27292471 -0.5106188 ]
#  [-0.66360075  0.70154119  0.22513869  1.26009375]]
